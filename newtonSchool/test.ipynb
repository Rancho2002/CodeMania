# %%
import os
from math import log10

files=os.listdir(".")

files.sort(key=lambda x: os.path.getmtime(x))
# print(files) # list index 0 hold the oldest file
digits=int(log10(len(files)))+1

rename=0

for i in range(len(files)-1):
    if(files[i][0]=="."):
        rename-=1
        continue

    if "_" in files[i] and files[i][0]!="_":
        index=files[i].find("_")
        isNum=files[index-1]
    
        if(isNum >="0" and isNum<="9"):
            oldName=files[i][index+1:]
        else:
            oldName=files[i]
    else:
        oldName=files[i]

    rename+=1
    
    newfile_name=f"{str(rename+1).zfill(digits)}_{oldName}"
    # os.rename(files[i],newfile_name)
    print(newfile_name)
    # print(oldName)
# Out:
# 02_(unsolved)pencil.py
# 03_money.py
# 04_tellDate.py
# 05_test.exe
# 06_fearballon.exe
# 07_fearballon.cpp
# 08_fearBallon.py
# 09_family.py
# 10_camp.py
# 11_grid.py
# 12_grid.cpp
# 13_endcard.py
# 14_timeDilation.py
# 15_dilation.cpp
# 16_dilation.exe
# 17_newtogon.py
# 18_pointDance.py
# 19_xorprob.cpp
# 20_xorprob.exe
# 21_XorProblem.py
# 22_findProsum.py
# 23_prosum.c
# 24_lettergame.py
# 25_test.py
# 26_bustorwin.py
# 27_goldmagic.py
# 28_calculateInverse.py
# 29_redorstring.py
# 30_stringram.py
# 31_christmasOrNewyear.py
# 32_nearEqual.py
# 33_distance.py
# 34_brokenNews.py
# 35_stringing.py
# 36_GreedyNewton.py
# 37_rightPrime.c
# 38_rightPrime.exe
# 39_Strongidrome.py
# 40_MallCoupons.py
# 41_friendsorNot.py
# 42_Maths-Competition.py
# 43_Even Numbers - 2.py
# 44_Emily and Triplets.py
# 45_AbhasandNumbers.py
# 46_MatchingStrings.py
# 47_ContiguousSubstring.py
# 48_Bacterias.py
# 49_UnluckySeven.py
# 50_Play0and2.py
# 51_coderushQ1.py
# 52_mex.py
# 53_alexa.py
# 54_bobExam.py
# 55_prefix.py
# 56_reverseStr.py
# 57_carryOrNot.py
# 58_Alexa and Balls.py
# 59_chipmunk.py
# 60_bobDigit.py
# 61_shifted-string.py
# 62_cards-shuffle.py
# 63_String-Sequence.py
# 64_multiple3.py
# 65_MaximumSumCards.py
# 66_NumberGames.py
# 67_MinimumReplacements.py
# 68_MaximiseProduct.py
# 69_Alexa-and-digits.py
# 70_maximum-operations.c
# 71_playwithZeroes.py
# 72_cardGames.py
# 73_minimizeStamina.py
# 74_painterProblem.py
# 75_perfectNum.py
# 76_non3.py
# 77_divison1.py
